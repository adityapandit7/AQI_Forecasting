# %% [markdown]
# import libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import hydroeval as he

# %% [markdown]
# model library

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
#from keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import SGD,RMSprop,Adam,Adadelta,Adagrad,Adamax,Nadam

# %% [markdown]
# hyper parameter tuner

# %%
import keras_tuner as kt
import time
# model checkpoint
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError,MeanAbsoluteError
from tensorflow.keras.metrics import RootMeanSquaredError

# %% [markdown]
# loss test

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# load dataset

# %%
# def load_dataset(path):
#     return pd.read_csv(path)


# file_path = r"C:\Users\Acer\Desktop\Testing\preprocessed_dataset.csv"
# df= load_dataset(file_path)

# df

# %% [markdown]
# features define

# %%
# import datetime

# def str_to_datetime(s):
#     split = s.split('/')
#     month,day,year = int(split[0]),int(split[1]),int(split[2])

#     return datetime.datetime(year=year,month=month,day=day)

# %%
df = pd.read_csv('preprocessed_dataset_china.csv',index_col=0)

# %%
df.head()
# Out:
#                   PM2.5        O3  TEMPERATURE  PRESSURE  DEWPOINT  RAIN
# date_and_time
# 3/1/2013 0:00  0.006024  0.172689     0.297909  0.646749  0.255486   0.0
# 3/1/2013 1:00  0.008032  0.183869     0.290941  0.655536  0.250784   0.0
# 3/1/2013 2:00  0.005020  0.164304     0.282230  0.659051  0.244514   0.0
# 3/1/2013 4:00  0.005020  0.100020     0.277003  0.685413  0.213166   0.0
# 3/1/2013 5:00  0.007028  0.178279     0.264808  0.695958  0.222571   0.0

# %%
features = ["PM2.5",	"O3",	"TEMPERATURE",	"PRESSURE",	"DEWPOINT", 	"RAIN"]
df = df[features]

# %%
import numpy as np

mean_pm = df['PM2.5'].mean()
std_pm = df['PM2.5'].std()
z_scores = (df['PM2.5'] - mean_pm) / std_pm

threshold = 3
df = df[np.abs(z_scores) < threshold]

# %% [markdown]
# adding window

# %%
def df_to_X_y(df, window_size = 5):
    df_as_np = df.to_numpy()
    X = []
    y = []
    for i in range(len(df_as_np)-window_size):
        row = [r for r in df_as_np[i:i+window_size]]
        X.append(row)
        label = df_as_np[i+window_size][0]
        y.append(label)
    return np.array(X), np.array(y)

WINDOW_SIZE = 2

X, y = df_to_X_y(df,WINDOW_SIZE)

X.shape, y.shape
# Out:
# ((33038, 2, 6), (33038,))

# %% [markdown]
# import

# %%
import numpy as np
from sklearn.model_selection import KFold, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import ParameterGrid

from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# Developing transformer model

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Normalization and Attention
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(x, x)
    x = layers.Dropout(dropout)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.LayerNormalization(epsilon=1e-6)(res)
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    return x + res

from tensorflow.keras.callbacks import EarlyStopping

def build_model(hp):
    inputs = keras.Input(shape=input_shape)
    x = inputs

    for i in range(hp.Int('num_transformer_blocks', min_value=2, max_value=8, step=2)):
        x = transformer_encoder(x,
                               hp.Int('head_size', min_value=8, max_value=256, step=32),
                               hp.Int('num_heads', min_value=2, max_value=16),
                               hp.Int('ff_dim', min_value=4, max_value=64),
                               hp.Float(f'dropout_{i}', min_value=0.1, max_value=0.6))

    x = layers.GlobalAveragePooling1D(data_format="channels_first")(x)

    for i in range(hp.Int('num_mlp_layers', min_value=1, max_value=3)):
        x = layers.Dense(hp.Int(f'mlp_units_{i}', min_value=32, max_value=256, step=32))(x)
        x = layers.Activation('relu')(x)
        x = layers.Dropout(hp.Float(f'mlp_dropout_{i}', min_value=0.1, max_value=0.6))(x)

    outputs = layers.Dense(1)(x)
    model = keras.Model(inputs, outputs)

    # Choose optimizer and learning rate
    optimizer = hp.Choice('optimizer', values=['adam', 'adamax'])
    learning_rate = hp.Float('learning_rate', min_value=1e-4, max_value=1e-2)

    if optimizer == 'adam':
        opt = Adam(learning_rate=learning_rate)
    else:
        opt = Adamax(learning_rate=learning_rate, beta_1=0.9, beta_2=0.999)

    model.compile(optimizer=opt, loss=MeanSquaredError(), metrics=['mae', RootMeanSquaredError()])

    return model

# %%
input_shape = X.shape[1:]
input_shape
# Out:
# (2, 6)

# %% [markdown]
# importing for training

# %%
import numpy as np
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from kerastuner.tuners import RandomSearch
from kerastuner.engine.hyperparameters import HyperParameters
import keras_tuner as kt
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_832\2235316674.py:7: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   from kerastuner.tuners import RandomSearch

# %% [markdown]
# Model Building

# %%
input_shape = X.shape[1:]


best_model_hyperparameters = None
best_model_mae = float('inf')

worst_model_hyperparameters = None
worst_model_mae = float('-inf')


outer_cv = KFold(n_splits=5, shuffle=True, random_state=42)


nested_scores = []

for fold_outer_idx, (train_ix, test_ix) in enumerate(outer_cv.split(X)):
    X_train_outer, X_test_outer = X[train_ix], X[test_ix]
    y_train_outer, y_test_outer = y[train_ix], y[test_ix]

    inner_cv = KFold(n_splits=3, shuffle=True, random_state=42)

    for fold_idx, (train_ix_inner, val_ix) in enumerate(inner_cv.split(X_train_outer)):
        X_train_inner, X_val = X_train_outer[train_ix_inner], X_train_outer[val_ix]
        y_train_inner, y_val = y_train_outer[train_ix_inner], y_train_outer[val_ix]

        tuner = kt.RandomSearch(
            build_model,
            objective='val_loss',
            max_trials=3,

        directory = f'C:/Users/Administrator/Documents/GitHub/AQI_Forecasting/Hp_Tr_China/keras_tuner_random_dir_fold_tf_{fold_outer_idx}_{fold_idx}',
        project_name = f'C:/Users/Administrator/Documents/GitHub/AQI_Forecasting/Hp_Tr_China/hyperparameter_random_tuning_fold_tf_{fold_outer_idx}_{fold_idx}'
        )

        tuner.search(X_train_inner, y_train_inner, validation_data=(X_val, y_val), epochs=30)

        best_hps = tuner.oracle.get_best_trials(1)[0].hyperparameters
        print(f"Best hyperparameters for fold {fold_idx}: {best_hps}")

        model = build_model(best_hps)
        es = [keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)]

        model.fit(
            X_train_inner,
            y_train_inner,
            validation_data=(X_val, y_val),
            epochs=10,
            batch_size=32,
            callbacks=[es],
        )

        y_pred = model.predict(X_val)
        mae = mean_squared_error(y_val, y_pred)

        if mae < best_model_mae:
            best_model_mae = mae
            best_model_hyperparameters = best_hps
            best_model = model

        if mae > worst_model_mae:
            worst_model_mae = mae
            worst_model_hyperparameters = best_hps
            worst_model = model


    start_time = time.time()
    y_pred_best = best_model.predict(X_test_outer)
    y_pred_worst = worst_model.predict(X_test_outer)
    end_time = time.time()

    mse_best = mean_squared_error(y_test_outer, y_pred_best)
    mae_best = mean_absolute_error(y_test_outer, y_pred_best)
    rmse_best = np.sqrt(mse_best)

    r2_best = r2_score(y_test_outer, y_pred_best)
    time_duration = end_time - start_time

    mse_worst = mean_squared_error(y_test_outer, y_pred_worst)
    mae_worst = mean_absolute_error(y_test_outer, y_pred_worst)
    rmse_worst = np.sqrt(mse_worst)

    r2_worst = r2_score(y_test_outer, y_pred_worst)
    time_duration = end_time - start_time

    nested_scores.append({
        "Best Model": {
            "MSE": mse_best,
            "R^2": r2_best,
            "RMSE": rmse_best,
            "MAE": mae_best,
            "testing time": time_duration,
        },
        "Worst Model": {
            "MSE": mse_worst,
            "R^2": r2_worst,
            "RMSE": rmse_worst,
            "MAE": mae_worst,
            "testing time": time_duration,
        }
    })


print("Best Hyperparameters:", best_model_hyperparameters)
print("Best MAE:", best_model_mae)

print("Worst Hyperparameters:", worst_model_hyperparameters)
print("Worst MAE:", worst_model_mae)


print("Nested Cross-Validation Scores:")
for i, scores in enumerate(nested_scores):
    print(f"/nFold {i + 1} - MSE: {scores['Best Model']['MSE']}, R^2: {scores['Best Model']['R^2']}, 
    RMSE: {scores['Best Model']['RMSE']}, MAE: {scores['Best Model']['MAE']}")
# Out:
# Reloading Tuner from C:/Users/Administrator/Documents/GitHub/AQI_Forecasting/Hp_Tr_China/hyperparameter_random_tuning_fold_tf_0_0\tuner0.json
# Best hyperparameters for fold 0: <keras_tuner.src.engine.hyperparameters.hyperparameters.HyperParameters object at 0x000002B769FB0B90>
# Epoch 1/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - loss: 0.0067 - mae: 0.0534 - root_mean_squared_error: 0.0775 - val_loss: 0.0017 - val_mae: 0.0335 - val_root_mean_squared_error: 0.0414
# Epoch 2/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - loss: 0.0014 - mae: 0.0267 - root_mean_squared_error: 0.0368 - val_loss: 8.1410e-04 - val_mae: 0.0194 - val_root_mean_squared_error: 0.0285
# Epoch 3/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - loss: 0.0011 - mae: 0.0237 - root_mean_squared_error: 0.0331 - val_loss: 8.0768e-04 - val_mae: 0.0183 - val_root_mean_squared_error: 0.0284
# Epoch 4/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - loss: 0.0011 - mae: 0.0239 - root_mean_squared_error: 0.0335 - val_loss: 0.0014 - val_mae: 0.0299 - val_root_mean_squared_error: 0.0379
# Epoch 5/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - loss: 0.0012 - mae: 0.0243 - root_mean_squared_error: 0.0340 - val_loss: 8.7886e-04 - val_mae: 0.0208 - val_root_mean_squared_error: 0.0296
# Epoch 6/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - loss: 0.0012 - mae: 0.0249 - root_mean_squared_error: 0.0347 - val_loss: 8.6025e-04 - val_mae: 0.0195 - val_root_mean_squared_error: 0.0293
# Epoch 7/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - loss: 0.0011 - mae: 0.0235 - root_mean_squared_error: 0.0332 - val_loss: 8.4529e-04 - val_mae: 0.0209 - val_root_mean_squared_error: 0.0291
# Epoch 8/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - loss: 0.0011 - mae: 0.0239 - root_mean_squared_error: 0.0332 - val_loss: 8.7882e-04 - val_mae: 0.0209 - val_root_mean_squared_error: 0.0296
# Epoch 9/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - loss: 0.0012 - mae: 0.0241 - root_mean_squared_error: 0.0339 - val_loss: 9.8083e-04 - val_mae: 0.0212 - val_root_mean_squared_error: 0.0313
# Epoch 10/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - loss: 0.0011 - mae: 0.0235 - root_mean_squared_error: 0.0331 - val_loss: 8.6305e-04 - val_mae: 0.0196 - val_root_mean_squared_error: 0.0294
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# Reloading Tuner from C:/Users/Administrator/Documents/GitHub/AQI_Forecasting/Hp_Tr_China/hyperparameter_random_tuning_fold_tf_0_1\tuner0.json
# Best hyperparameters for fold 1: <keras_tuner.src.engine.hyperparameters.hyperparameters.HyperParameters object at 0x000002B721DABEF0>
# Epoch 1/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - loss: 0.0102 - mae: 0.0684 - root_mean_squared_error: 0.0961 - val_loss: 0.0034 - val_mae: 0.0426 - val_root_mean_squared_error: 0.0587
# Epoch 2/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - loss: 0.0026 - mae: 0.0390 - root_mean_squared_error: 0.0510 - val_loss: 0.0011 - val_mae: 0.0243 - val_root_mean_squared_error: 0.0327
# Epoch 3/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - loss: 0.0015 - mae: 0.0277 - root_mean_squared_error: 0.0381 - val_loss: 0.0011 - val_mae: 0.0241 - val_root_mean_squared_error: 0.0337
# Epoch 4/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 0.0012 - mae: 0.0248 - root_mean_squared_error: 0.0350 - val_loss: 9.4294e-04 - val_mae: 0.0210 - val_root_mean_squared_error: 0.0307
# Epoch 5/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 0.0012 - mae: 0.0241 - root_mean_squared_error: 0.0340 - val_loss: 7.9968e-04 - val_mae: 0.0189 - val_root_mean_squared_error: 0.0283
# Epoch 6/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - loss: 0.0011 - mae: 0.0226 - root_mean_squared_error: 0.0327 - val_loss: 7.9461e-04 - val_mae: 0.0197 - val_root_mean_squared_error: 0.0282
# Epoch 7/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - loss: 0.0010 - mae: 0.0226 - root_mean_squared_error: 0.0324 - val_loss: 7.4514e-04 - val_mae: 0.0185 - val_root_mean_squared_error: 0.0273
# Epoch 8/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - loss: 9.8708e-04 - mae: 0.0218 - root_mean_squared_error: 0.0314 - val_loss: 8.7025e-04 - val_mae: 0.0195 - val_root_mean_squared_error: 0.0295
# Epoch 9/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step - loss: 9.9356e-04 - mae: 0.0221 - root_mean_squared_error: 0.0315 - val_loss: 8.9612e-04 - val_mae: 0.0200 - val_root_mean_squared_error: 0.0299
# Epoch 10/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - loss: 9.6640e-04 - mae: 0.0217 - root_mean_squared_error: 0.0311 - val_loss: 7.9025e-04 - val_mae: 0.0193 - val_root_mean_squared_error: 0.0281
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
# Reloading Tuner from C:/Users/Administrator/Documents/GitHub/AQI_Forecasting/Hp_Tr_China/hyperparameter_random_tuning_fold_tf_0_2\tuner0.json
# Best hyperparameters for fold 2: <keras_tuner.src.engine.hyperparameters.hyperparameters.HyperParameters object at 0x000002B775D1EFC0>
# Epoch 1/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 50s 61ms/step - loss: 0.0390 - mae: 0.1010 - root_mean_squared_error: 0.1742 - val_loss: 9.3293e-04 - val_mae: 0.0242 - val_root_mean_squared_error: 0.0305
# Epoch 2/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 32s 58ms/step - loss: 0.0018 - mae: 0.0313 - root_mean_squared_error: 0.0427 - val_loss: 9.5371e-04 - val_mae: 0.0243 - val_root_mean_squared_error: 0.0309
# Epoch 3/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 31s 57ms/step - loss: 0.0013 - mae: 0.0257 - root_mean_squared_error: 0.0358 - val_loss: 9.2880e-04 - val_mae: 0.0223 - val_root_mean_squared_error: 0.0305
# Epoch 4/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 31s 57ms/step - loss: 0.0011 - mae: 0.0229 - root_mean_squared_error: 0.0326 - val_loss: 6.9366e-04 - val_mae: 0.0191 - val_root_mean_squared_error: 0.0263
# Epoch 5/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 31s 57ms/step - loss: 0.0010 - mae: 0.0222 - root_mean_squared_error: 0.0324 - val_loss: 7.6254e-04 - val_mae: 0.0193 - val_root_mean_squared_error: 0.0276
# Epoch 6/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 31s 56ms/step - loss: 9.4059e-04 - mae: 0.0210 - root_mean_squared_error: 0.0307 - val_loss: 5.8824e-04 - val_mae: 0.0163 - val_root_mean_squared_error: 0.0243
# Epoch 7/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 31s 57ms/step - loss: 9.2759e-04 - mae: 0.0210 - root_mean_squared_error: 0.0304 - val_loss: 8.3303e-04 - val_mae: 0.0230 - val_root_mean_squared_error: 0.0289
# Epoch 8/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 31s 56ms/step - loss: 9.4665e-04 - mae: 0.0213 - root_mean_squared_error: 0.0308 - val_loss: 0.0011 - val_mae: 0.0226 - val_root_mean_squared_error: 0.0331
# Epoch 9/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 31s 56ms/step - loss: 9.4652e-04 - mae: 0.0214 - root_mean_squared_error: 0.0308 - val_loss: 8.3611e-04 - val_mae: 0.0192 - val_root_mean_squared_error: 0.0289
# Epoch 10/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 31s 57ms/step - loss: 9.3014e-04 - mae: 0.0210 - root_mean_squared_error: 0.0305 - val_loss: 7.3832e-04 - val_mae: 0.0178 - val_root_mean_squared_error: 0.0272
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 8s 27ms/step
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step
# Reloading Tuner from C:/Users/Administrator/Documents/GitHub/AQI_Forecasting/Hp_Tr_China/hyperparameter_random_tuning_fold_tf_1_0\tuner0.json
# Best hyperparameters for fold 0: <keras_tuner.src.engine.hyperparameters.hyperparameters.HyperParameters object at 0x000002B782ADC620>
# Epoch 1/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0047 - mae: 0.0485 - root_mean_squared_error: 0.0661 - val_loss: 7.1340e-04 - val_mae: 0.0186 - val_root_mean_squared_error: 0.0267
# Epoch 2/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 0.0013 - mae: 0.0253 - root_mean_squared_error: 0.0356 - val_loss: 7.2537e-04 - val_mae: 0.0198 - val_root_mean_squared_error: 0.0269
# Epoch 3/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 0.0012 - mae: 0.0245 - root_mean_squared_error: 0.0348 - val_loss: 8.4410e-04 - val_mae: 0.0214 - val_root_mean_squared_error: 0.0291
# Epoch 4/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0011 - mae: 0.0239 - root_mean_squared_error: 0.0337 - val_loss: 0.0011 - val_mae: 0.0280 - val_root_mean_squared_error: 0.0335
# Epoch 5/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 0.0011 - mae: 0.0234 - root_mean_squared_error: 0.0326 - val_loss: 7.8523e-04 - val_mae: 0.0208 - val_root_mean_squared_error: 0.0280
# Epoch 6/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 0.0010 - mae: 0.0227 - root_mean_squared_error: 0.0316 - val_loss: 7.2495e-04 - val_mae: 0.0193 - val_root_mean_squared_error: 0.0269
# Epoch 7/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 9.2382e-04 - mae: 0.0215 - root_mean_squared_error: 0.0304 - val_loss: 5.3128e-04 - val_mae: 0.0151 - val_root_mean_squared_error: 0.0230
# Epoch 8/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 7.5214e-04 - mae: 0.0189 - root_mean_squared_error: 0.0274 - val_loss: 5.3020e-04 - val_mae: 0.0160 - val_root_mean_squared_error: 0.0230
# Epoch 9/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 6.8956e-04 - mae: 0.0183 - root_mean_squared_error: 0.0263 - val_loss: 5.7533e-04 - val_mae: 0.0162 - val_root_mean_squared_error: 0.0240
# Epoch 10/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 6.5703e-04 - mae: 0.0177 - root_mean_squared_error: 0.0256 - val_loss: 4.4271e-04 - val_mae: 0.0123 - val_root_mean_squared_error: 0.0210
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# Reloading Tuner from C:/Users/Administrator/Documents/GitHub/AQI_Forecasting/Hp_Tr_China/hyperparameter_random_tuning_fold_tf_1_1\tuner0.json
# Best hyperparameters for fold 1: <keras_tuner.src.engine.hyperparameters.hyperparameters.HyperParameters object at 0x000002B76F6864E0>
# Epoch 1/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 17s 19ms/step - loss: 0.0073 - mae: 0.0598 - root_mean_squared_error: 0.0824 - val_loss: 8.5969e-04 - val_mae: 0.0221 - val_root_mean_squared_error: 0.0293
# Epoch 2/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - loss: 0.0013 - mae: 0.0256 - root_mean_squared_error: 0.0360 - val_loss: 7.3020e-04 - val_mae: 0.0200 - val_root_mean_squared_error: 0.0270
# Epoch 3/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - loss: 0.0011 - mae: 0.0228 - root_mean_squared_error: 0.0329 - val_loss: 0.0012 - val_mae: 0.0244 - val_root_mean_squared_error: 0.0346
# Epoch 4/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - loss: 0.0011 - mae: 0.0232 - root_mean_squared_error: 0.0330 - val_loss: 9.0574e-04 - val_mae: 0.0201 - val_root_mean_squared_error: 0.0301
# Epoch 5/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 0.0011 - mae: 0.0226 - root_mean_squared_error: 0.0326 - val_loss: 6.8266e-04 - val_mae: 0.0177 - val_root_mean_squared_error: 0.0261
# Epoch 6/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - loss: 9.6468e-04 - mae: 0.0216 - root_mean_squared_error: 0.0311 - val_loss: 7.2675e-04 - val_mae: 0.0197 - val_root_mean_squared_error: 0.0270
# Epoch 7/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - loss: 9.6784e-04 - mae: 0.0216 - root_mean_squared_error: 0.0311 - val_loss: 6.6110e-04 - val_mae: 0.0172 - val_root_mean_squared_error: 0.0257
# Epoch 8/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 0.0011 - mae: 0.0227 - root_mean_squared_error: 0.0327 - val_loss: 7.4418e-04 - val_mae: 0.0204 - val_root_mean_squared_error: 0.0273
# Epoch 9/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - loss: 9.7754e-04 - mae: 0.0215 - root_mean_squared_error: 0.0312 - val_loss: 8.1275e-04 - val_mae: 0.0212 - val_root_mean_squared_error: 0.0285
# Epoch 10/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 0.0010 - mae: 0.0220 - root_mean_squared_error: 0.0319 - val_loss: 6.7853e-04 - val_mae: 0.0182 - val_root_mean_squared_error: 0.0260
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step
# Reloading Tuner from C:/Users/Administrator/Documents/GitHub/AQI_Forecasting/Hp_Tr_China/hyperparameter_random_tuning_fold_tf_1_2\tuner0.json
# Best hyperparameters for fold 2: <keras_tuner.src.engine.hyperparameters.hyperparameters.HyperParameters object at 0x000002B78AD64200>
# Epoch 1/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 22s 23ms/step - loss: 0.0078 - mae: 0.0647 - root_mean_squared_error: 0.0862 - val_loss: 0.0014 - val_mae: 0.0292 - val_root_mean_squared_error: 0.0368
# Epoch 2/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 13s 23ms/step - loss: 0.0025 - mae: 0.0373 - root_mean_squared_error: 0.0495 - val_loss: 0.0011 - val_mae: 0.0236 - val_root_mean_squared_error: 0.0326
# Epoch 3/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - loss: 0.0018 - mae: 0.0312 - root_mean_squared_error: 0.0422 - val_loss: 9.6728e-04 - val_mae: 0.0210 - val_root_mean_squared_error: 0.0311
# Epoch 4/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - loss: 0.0015 - mae: 0.0285 - root_mean_squared_error: 0.0392 - val_loss: 9.9509e-04 - val_mae: 0.0226 - val_root_mean_squared_error: 0.0315
# Epoch 5/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 12s 21ms/step - loss: 0.0014 - mae: 0.0280 - root_mean_squared_error: 0.0380 - val_loss: 8.3723e-04 - val_mae: 0.0190 - val_root_mean_squared_error: 0.0289
# Epoch 6/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - loss: 0.0014 - mae: 0.0266 - root_mean_squared_error: 0.0370 - val_loss: 7.6812e-04 - val_mae: 0.0183 - val_root_mean_squared_error: 0.0277
# Epoch 7/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - loss: 0.0012 - mae: 0.0256 - root_mean_squared_error: 0.0352 - val_loss: 9.5881e-04 - val_mae: 0.0217 - val_root_mean_squared_error: 0.0310
# Epoch 8/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.0012 - mae: 0.0247 - root_mean_squared_error: 0.0345 - val_loss: 0.0011 - val_mae: 0.0262 - val_root_mean_squared_error: 0.0335
# Epoch 9/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.0012 - mae: 0.0249 - root_mean_squared_error: 0.0348 - val_loss: 9.6481e-04 - val_mae: 0.0233 - val_root_mean_squared_error: 0.0311
# Epoch 10/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - loss: 0.0012 - mae: 0.0243 - root_mean_squared_error: 0.0341 - val_loss: 0.0010 - val_mae: 0.0220 - val_root_mean_squared_error: 0.0319
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# Reloading Tuner from C:/Users/Administrator/Documents/GitHub/AQI_Forecasting/Hp_Tr_China/hyperparameter_random_tuning_fold_tf_2_0\tuner0.json
# Best hyperparameters for fold 0: <keras_tuner.src.engine.hyperparameters.hyperparameters.HyperParameters object at 0x000002B798EC1A90>
# Epoch 1/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 32s 33ms/step - loss: 0.0106 - mae: 0.0706 - root_mean_squared_error: 0.0980 - val_loss: 0.0029 - val_mae: 0.0412 - val_root_mean_squared_error: 0.0537
# Epoch 2/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 17s 31ms/step - loss: 0.0030 - mae: 0.0421 - root_mean_squared_error: 0.0548 - val_loss: 0.0010 - val_mae: 0.0242 - val_root_mean_squared_error: 0.0317
# Epoch 3/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 17s 31ms/step - loss: 0.0017 - mae: 0.0303 - root_mean_squared_error: 0.0410 - val_loss: 8.7711e-04 - val_mae: 0.0218 - val_root_mean_squared_error: 0.0296
# Epoch 4/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 17s 31ms/step - loss: 0.0014 - mae: 0.0271 - root_mean_squared_error: 0.0374 - val_loss: 8.1742e-04 - val_mae: 0.0195 - val_root_mean_squared_error: 0.0286
# Epoch 5/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 17s 31ms/step - loss: 0.0012 - mae: 0.0243 - root_mean_squared_error: 0.0343 - val_loss: 7.8704e-04 - val_mae: 0.0196 - val_root_mean_squared_error: 0.0281
# Epoch 6/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 17s 31ms/step - loss: 0.0011 - mae: 0.0231 - root_mean_squared_error: 0.0331 - val_loss: 9.8675e-04 - val_mae: 0.0206 - val_root_mean_squared_error: 0.0314
# Epoch 7/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 18s 32ms/step - loss: 0.0011 - mae: 0.0224 - root_mean_squared_error: 0.0324 - val_loss: 8.9698e-04 - val_mae: 0.0227 - val_root_mean_squared_error: 0.0299
# Epoch 8/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 19s 35ms/step - loss: 0.0010 - mae: 0.0226 - root_mean_squared_error: 0.0323 - val_loss: 0.0010 - val_mae: 0.0203 - val_root_mean_squared_error: 0.0316
# Epoch 9/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 18s 32ms/step - loss: 0.0010 - mae: 0.0223 - root_mean_squared_error: 0.0322 - val_loss: 9.0070e-04 - val_mae: 0.0193 - val_root_mean_squared_error: 0.0300
# Epoch 10/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 18s 32ms/step - loss: 9.9045e-04 - mae: 0.0218 - root_mean_squared_error: 0.0315 - val_loss: 7.1089e-04 - val_mae: 0.0180 - val_root_mean_squared_error: 0.0267
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step
# Reloading Tuner from C:/Users/Administrator/Documents/GitHub/AQI_Forecasting/Hp_Tr_China/hyperparameter_random_tuning_fold_tf_2_1\tuner0.json
# Best hyperparameters for fold 1: <keras_tuner.src.engine.hyperparameters.hyperparameters.HyperParameters object at 0x000002B798F574A0>
# Epoch 1/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 23s 29ms/step - loss: 0.0064 - mae: 0.0542 - root_mean_squared_error: 0.0760 - val_loss: 8.6488e-04 - val_mae: 0.0222 - val_root_mean_squared_error: 0.0294
# Epoch 2/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 16s 29ms/step - loss: 0.0013 - mae: 0.0262 - root_mean_squared_error: 0.0366 - val_loss: 0.0012 - val_mae: 0.0276 - val_root_mean_squared_error: 0.0343
# Epoch 3/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - loss: 0.0012 - mae: 0.0245 - root_mean_squared_error: 0.0348 - val_loss: 6.8903e-04 - val_mae: 0.0176 - val_root_mean_squared_error: 0.0262
# Epoch 4/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - loss: 0.0011 - mae: 0.0239 - root_mean_squared_error: 0.0337 - val_loss: 0.0010 - val_mae: 0.0224 - val_root_mean_squared_error: 0.0324
# Epoch 5/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - loss: 0.0011 - mae: 0.0228 - root_mean_squared_error: 0.0328 - val_loss: 6.0214e-04 - val_mae: 0.0157 - val_root_mean_squared_error: 0.0245
# Epoch 6/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - loss: 0.0011 - mae: 0.0230 - root_mean_squared_error: 0.0327 - val_loss: 7.0818e-04 - val_mae: 0.0186 - val_root_mean_squared_error: 0.0266
# Epoch 7/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - loss: 0.0012 - mae: 0.0239 - root_mean_squared_error: 0.0342 - val_loss: 5.6986e-04 - val_mae: 0.0149 - val_root_mean_squared_error: 0.0239
# Epoch 8/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - loss: 0.0012 - mae: 0.0241 - root_mean_squared_error: 0.0341 - val_loss: 8.8664e-04 - val_mae: 0.0227 - val_root_mean_squared_error: 0.0298
# Epoch 9/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - loss: 0.0011 - mae: 0.0233 - root_mean_squared_error: 0.0332 - val_loss: 7.4865e-04 - val_mae: 0.0200 - val_root_mean_squared_error: 0.0274
# Epoch 10/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - loss: 0.0012 - mae: 0.0243 - root_mean_squared_error: 0.0345 - val_loss: 9.4586e-04 - val_mae: 0.0234 - val_root_mean_squared_error: 0.0308
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step
# Reloading Tuner from C:/Users/Administrator/Documents/GitHub/AQI_Forecasting/Hp_Tr_China/hyperparameter_random_tuning_fold_tf_2_2\tuner0.json
# Best hyperparameters for fold 2: <keras_tuner.src.engine.hyperparameters.hyperparameters.HyperParameters object at 0x000002B79B5A5C70>
# Epoch 1/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 12s 14ms/step - loss: 0.0115 - mae: 0.0740 - root_mean_squared_error: 0.1027 - val_loss: 0.0011 - val_mae: 0.0255 - val_root_mean_squared_error: 0.0328
# Epoch 2/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - loss: 0.0023 - mae: 0.0352 - root_mean_squared_error: 0.0479 - val_loss: 0.0012 - val_mae: 0.0269 - val_root_mean_squared_error: 0.0343
# Epoch 3/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - loss: 0.0017 - mae: 0.0297 - root_mean_squared_error: 0.0410 - val_loss: 9.4195e-04 - val_mae: 0.0238 - val_root_mean_squared_error: 0.0307
# Epoch 4/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - loss: 0.0016 - mae: 0.0285 - root_mean_squared_error: 0.0399 - val_loss: 7.6997e-04 - val_mae: 0.0205 - val_root_mean_squared_error: 0.0277
# Epoch 5/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - loss: 0.0015 - mae: 0.0273 - root_mean_squared_error: 0.0387 - val_loss: 8.0898e-04 - val_mae: 0.0211 - val_root_mean_squared_error: 0.0284
# Epoch 6/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - loss: 0.0014 - mae: 0.0267 - root_mean_squared_error: 0.0371 - val_loss: 7.5599e-04 - val_mae: 0.0199 - val_root_mean_squared_error: 0.0275
# Epoch 7/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - loss: 0.0013 - mae: 0.0258 - root_mean_squared_error: 0.0362 - val_loss: 0.0010 - val_mae: 0.0261 - val_root_mean_squared_error: 0.0322
# Epoch 8/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 0.0013 - mae: 0.0253 - root_mean_squared_error: 0.0356 - val_loss: 7.5802e-04 - val_mae: 0.0204 - val_root_mean_squared_error: 0.0275
# Epoch 9/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - loss: 0.0012 - mae: 0.0250 - root_mean_squared_error: 0.0351 - val_loss: 7.1657e-04 - val_mae: 0.0194 - val_root_mean_squared_error: 0.0268
# Epoch 10/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - loss: 0.0012 - mae: 0.0247 - root_mean_squared_error: 0.0349 - val_loss: 7.8174e-04 - val_mae: 0.0210 - val_root_mean_squared_error: 0.0280
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step
# Reloading Tuner from C:/Users/Administrator/Documents/GitHub/AQI_Forecasting/Hp_Tr_China/hyperparameter_random_tuning_fold_tf_3_0\tuner0.json
# Best hyperparameters for fold 0: <keras_tuner.src.engine.hyperparameters.hyperparameters.HyperParameters object at 0x000002B7A18610D0>
# Epoch 1/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 21s 20ms/step - loss: 0.0081 - mae: 0.0663 - root_mean_squared_error: 0.0883 - val_loss: 0.0014 - val_mae: 0.0307 - val_root_mean_squared_error: 0.0376
# Epoch 2/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.0027 - mae: 0.0391 - root_mean_squared_error: 0.0522 - val_loss: 9.8700e-04 - val_mae: 0.0237 - val_root_mean_squared_error: 0.0314
# Epoch 3/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 0.0022 - mae: 0.0338 - root_mean_squared_error: 0.0464 - val_loss: 9.8392e-04 - val_mae: 0.0241 - val_root_mean_squared_error: 0.0314
# Epoch 4/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 0.0017 - mae: 0.0298 - root_mean_squared_error: 0.0407 - val_loss: 0.0011 - val_mae: 0.0267 - val_root_mean_squared_error: 0.0331
# Epoch 5/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 0.0014 - mae: 0.0268 - root_mean_squared_error: 0.0371 - val_loss: 8.0852e-04 - val_mae: 0.0210 - val_root_mean_squared_error: 0.0284
# Epoch 6/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 0.0013 - mae: 0.0260 - root_mean_squared_error: 0.0363 - val_loss: 7.2301e-04 - val_mae: 0.0180 - val_root_mean_squared_error: 0.0269
# Epoch 7/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - loss: 0.0012 - mae: 0.0247 - root_mean_squared_error: 0.0350 - val_loss: 9.2558e-04 - val_mae: 0.0209 - val_root_mean_squared_error: 0.0304
# Epoch 8/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 0.0012 - mae: 0.0238 - root_mean_squared_error: 0.0339 - val_loss: 9.7461e-04 - val_mae: 0.0210 - val_root_mean_squared_error: 0.0312
# Epoch 9/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - loss: 0.0012 - mae: 0.0245 - root_mean_squared_error: 0.0346 - val_loss: 7.7060e-04 - val_mae: 0.0189 - val_root_mean_squared_error: 0.0278
# Epoch 10/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - loss: 0.0012 - mae: 0.0235 - root_mean_squared_error: 0.0340 - val_loss: 8.7441e-04 - val_mae: 0.0221 - val_root_mean_squared_error: 0.0296
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step
# Reloading Tuner from C:/Users/Administrator/Documents/GitHub/AQI_Forecasting/Hp_Tr_China/hyperparameter_random_tuning_fold_tf_3_1\tuner0.json
# Best hyperparameters for fold 1: <keras_tuner.src.engine.hyperparameters.hyperparameters.HyperParameters object at 0x000002B7AD8A7530>
# Epoch 1/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - loss: 0.0036 - mae: 0.0432 - root_mean_squared_error: 0.0586 - val_loss: 8.5841e-04 - val_mae: 0.0214 - val_root_mean_squared_error: 0.0293
# Epoch 2/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 0.0011 - mae: 0.0237 - root_mean_squared_error: 0.0333 - val_loss: 9.5318e-04 - val_mae: 0.0241 - val_root_mean_squared_error: 0.0309
# Epoch 3/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 9.9119e-04 - mae: 0.0224 - root_mean_squared_error: 0.0315 - val_loss: 6.8478e-04 - val_mae: 0.0171 - val_root_mean_squared_error: 0.0262
# Epoch 4/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 9.9057e-04 - mae: 0.0222 - root_mean_squared_error: 0.0315 - val_loss: 7.3295e-04 - val_mae: 0.0194 - val_root_mean_squared_error: 0.0271
# Epoch 5/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 9.3659e-04 - mae: 0.0215 - root_mean_squared_error: 0.0306 - val_loss: 8.7688e-04 - val_mae: 0.0229 - val_root_mean_squared_error: 0.0296
# Epoch 6/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 9.0507e-04 - mae: 0.0210 - root_mean_squared_error: 0.0301 - val_loss: 6.7186e-04 - val_mae: 0.0174 - val_root_mean_squared_error: 0.0259
# Epoch 7/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 9.2851e-04 - mae: 0.0211 - root_mean_squared_error: 0.0305 - val_loss: 0.0015 - val_mae: 0.0298 - val_root_mean_squared_error: 0.0385
# Epoch 8/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 9.3911e-04 - mae: 0.0218 - root_mean_squared_error: 0.0306 - val_loss: 7.5667e-04 - val_mae: 0.0192 - val_root_mean_squared_error: 0.0275
# Epoch 9/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 0.0010 - mae: 0.0224 - root_mean_squared_error: 0.0318 - val_loss: 6.5231e-04 - val_mae: 0.0164 - val_root_mean_squared_error: 0.0255
# Epoch 10/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 9.2841e-04 - mae: 0.0210 - root_mean_squared_error: 0.0305 - val_loss: 8.2137e-04 - val_mae: 0.0211 - val_root_mean_squared_error: 0.0287
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# Reloading Tuner from C:/Users/Administrator/Documents/GitHub/AQI_Forecasting/Hp_Tr_China/hyperparameter_random_tuning_fold_tf_3_2\tuner0.json
# Best hyperparameters for fold 2: <keras_tuner.src.engine.hyperparameters.hyperparameters.HyperParameters object at 0x000002B7AD7680E0>
# Epoch 1/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 0.0110 - mae: 0.0706 - root_mean_squared_error: 0.1005 - val_loss: 9.5750e-04 - val_mae: 0.0237 - val_root_mean_squared_error: 0.0309
# Epoch 2/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - loss: 0.0017 - mae: 0.0304 - root_mean_squared_error: 0.0414 - val_loss: 7.0644e-04 - val_mae: 0.0185 - val_root_mean_squared_error: 0.0266
# Epoch 3/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - loss: 0.0012 - mae: 0.0251 - root_mean_squared_error: 0.0348 - val_loss: 7.9289e-04 - val_mae: 0.0191 - val_root_mean_squared_error: 0.0282
# Epoch 4/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - loss: 0.0011 - mae: 0.0239 - root_mean_squared_error: 0.0336 - val_loss: 7.1065e-04 - val_mae: 0.0181 - val_root_mean_squared_error: 0.0267
# Epoch 5/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 0.0010 - mae: 0.0232 - root_mean_squared_error: 0.0324 - val_loss: 6.6621e-04 - val_mae: 0.0172 - val_root_mean_squared_error: 0.0258
# Epoch 6/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - loss: 0.0010 - mae: 0.0230 - root_mean_squared_error: 0.0323 - val_loss: 6.9053e-04 - val_mae: 0.0184 - val_root_mean_squared_error: 0.0263
# Epoch 7/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 0.0010 - mae: 0.0223 - root_mean_squared_error: 0.0316 - val_loss: 8.4453e-04 - val_mae: 0.0193 - val_root_mean_squared_error: 0.0291
# Epoch 8/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - loss: 0.0010 - mae: 0.0226 - root_mean_squared_error: 0.0318 - val_loss: 9.0511e-04 - val_mae: 0.0215 - val_root_mean_squared_error: 0.0301
# Epoch 9/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - loss: 9.8869e-04 - mae: 0.0219 - root_mean_squared_error: 0.0314 - val_loss: 6.7842e-04 - val_mae: 0.0167 - val_root_mean_squared_error: 0.0260
# Epoch 10/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 9.3141e-04 - mae: 0.0211 - root_mean_squared_error: 0.0305 - val_loss: 7.5902e-04 - val_mae: 0.0181 - val_root_mean_squared_error: 0.0276
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step
# Reloading Tuner from C:/Users/Administrator/Documents/GitHub/AQI_Forecasting/Hp_Tr_China/hyperparameter_random_tuning_fold_tf_4_0\tuner0.json
# Best hyperparameters for fold 0: <keras_tuner.src.engine.hyperparameters.hyperparameters.HyperParameters object at 0x000002B7A8D3BD40>
# Epoch 1/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 30s 32ms/step - loss: 0.0119 - mae: 0.0746 - root_mean_squared_error: 0.1046 - val_loss: 0.0046 - val_mae: 0.0524 - val_root_mean_squared_error: 0.0680
# Epoch 2/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 17s 30ms/step - loss: 0.0041 - mae: 0.0494 - root_mean_squared_error: 0.0641 - val_loss: 0.0012 - val_mae: 0.0270 - val_root_mean_squared_error: 0.0346
# Epoch 3/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 17s 30ms/step - loss: 0.0018 - mae: 0.0316 - root_mean_squared_error: 0.0427 - val_loss: 8.2373e-04 - val_mae: 0.0217 - val_root_mean_squared_error: 0.0287
# Epoch 4/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 17s 30ms/step - loss: 0.0014 - mae: 0.0274 - root_mean_squared_error: 0.0374 - val_loss: 9.1426e-04 - val_mae: 0.0213 - val_root_mean_squared_error: 0.0302
# Epoch 5/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 17s 30ms/step - loss: 0.0013 - mae: 0.0259 - root_mean_squared_error: 0.0362 - val_loss: 9.1569e-04 - val_mae: 0.0209 - val_root_mean_squared_error: 0.0303
# Epoch 6/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 17s 31ms/step - loss: 0.0012 - mae: 0.0253 - root_mean_squared_error: 0.0351 - val_loss: 9.6651e-04 - val_mae: 0.0222 - val_root_mean_squared_error: 0.0311
# Epoch 7/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 17s 31ms/step - loss: 0.0012 - mae: 0.0245 - root_mean_squared_error: 0.0346 - val_loss: 8.1611e-04 - val_mae: 0.0204 - val_root_mean_squared_error: 0.0286
# Epoch 8/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 17s 31ms/step - loss: 0.0011 - mae: 0.0242 - root_mean_squared_error: 0.0336 - val_loss: 7.7216e-04 - val_mae: 0.0184 - val_root_mean_squared_error: 0.0278
# Epoch 9/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 17s 30ms/step - loss: 0.0011 - mae: 0.0236 - root_mean_squared_error: 0.0335 - val_loss: 7.8402e-04 - val_mae: 0.0209 - val_root_mean_squared_error: 0.0280
# Epoch 10/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 17s 30ms/step - loss: 0.0010 - mae: 0.0228 - root_mean_squared_error: 0.0321 - val_loss: 6.6420e-04 - val_mae: 0.0177 - val_root_mean_squared_error: 0.0258
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step
# Reloading Tuner from C:/Users/Administrator/Documents/GitHub/AQI_Forecasting/Hp_Tr_China/hyperparameter_random_tuning_fold_tf_4_1\tuner0.json
# Best hyperparameters for fold 1: <keras_tuner.src.engine.hyperparameters.hyperparameters.HyperParameters object at 0x000002B7C23CCBC0>
# Epoch 1/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - loss: 0.0085 - mae: 0.0647 - root_mean_squared_error: 0.0892 - val_loss: 8.6624e-04 - val_mae: 0.0227 - val_root_mean_squared_error: 0.0294
# Epoch 2/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - loss: 0.0016 - mae: 0.0294 - root_mean_squared_error: 0.0403 - val_loss: 7.8390e-04 - val_mae: 0.0208 - val_root_mean_squared_error: 0.0280
# Epoch 3/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - loss: 0.0013 - mae: 0.0260 - root_mean_squared_error: 0.0361 - val_loss: 6.5607e-04 - val_mae: 0.0181 - val_root_mean_squared_error: 0.0256
# Epoch 4/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - loss: 0.0012 - mae: 0.0240 - root_mean_squared_error: 0.0339 - val_loss: 7.0974e-04 - val_mae: 0.0181 - val_root_mean_squared_error: 0.0266
# Epoch 5/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - loss: 0.0012 - mae: 0.0241 - root_mean_squared_error: 0.0345 - val_loss: 7.4929e-04 - val_mae: 0.0187 - val_root_mean_squared_error: 0.0274
# Epoch 6/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - loss: 0.0011 - mae: 0.0236 - root_mean_squared_error: 0.0331 - val_loss: 6.2342e-04 - val_mae: 0.0161 - val_root_mean_squared_error: 0.0250
# Epoch 7/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - loss: 0.0011 - mae: 0.0229 - root_mean_squared_error: 0.0327 - val_loss: 8.3441e-04 - val_mae: 0.0208 - val_root_mean_squared_error: 0.0289
# Epoch 8/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - loss: 0.0010 - mae: 0.0229 - root_mean_squared_error: 0.0324 - val_loss: 7.5196e-04 - val_mae: 0.0203 - val_root_mean_squared_error: 0.0274
# Epoch 9/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - loss: 0.0010 - mae: 0.0223 - root_mean_squared_error: 0.0321 - val_loss: 7.3450e-04 - val_mae: 0.0183 - val_root_mean_squared_error: 0.0271
# Epoch 10/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - loss: 9.7783e-04 - mae: 0.0220 - root_mean_squared_error: 0.0313 - val_loss: 6.9721e-04 - val_mae: 0.0190 - val_root_mean_squared_error: 0.0264
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# Reloading Tuner from C:/Users/Administrator/Documents/GitHub/AQI_Forecasting/Hp_Tr_China/hyperparameter_random_tuning_fold_tf_4_2\tuner0.json
# Best hyperparameters for fold 2: <keras_tuner.src.engine.hyperparameters.hyperparameters.HyperParameters object at 0x000002B79FCF26C0>
# Epoch 1/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 25s 32ms/step - loss: 0.0039 - mae: 0.0457 - root_mean_squared_error: 0.0613 - val_loss: 0.0013 - val_mae: 0.0282 - val_root_mean_squared_error: 0.0366
# Epoch 2/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - loss: 0.0012 - mae: 0.0251 - root_mean_squared_error: 0.0351 - val_loss: 9.2259e-04 - val_mae: 0.0225 - val_root_mean_squared_error: 0.0304
# Epoch 3/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - loss: 0.0010 - mae: 0.0224 - root_mean_squared_error: 0.0317 - val_loss: 9.2130e-04 - val_mae: 0.0226 - val_root_mean_squared_error: 0.0304
# Epoch 4/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 16s 29ms/step - loss: 9.3273e-04 - mae: 0.0212 - root_mean_squared_error: 0.0305 - val_loss: 7.7646e-04 - val_mae: 0.0193 - val_root_mean_squared_error: 0.0279
# Epoch 5/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 16s 29ms/step - loss: 8.7919e-04 - mae: 0.0207 - root_mean_squared_error: 0.0296 - val_loss: 9.7722e-04 - val_mae: 0.0241 - val_root_mean_squared_error: 0.0313
# Epoch 6/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 16s 29ms/step - loss: 8.6588e-04 - mae: 0.0200 - root_mean_squared_error: 0.0294 - val_loss: 6.8385e-04 - val_mae: 0.0172 - val_root_mean_squared_error: 0.0262
# Epoch 7/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 16s 29ms/step - loss: 8.3103e-04 - mae: 0.0198 - root_mean_squared_error: 0.0288 - val_loss: 7.1655e-04 - val_mae: 0.0188 - val_root_mean_squared_error: 0.0268
# Epoch 8/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 16s 29ms/step - loss: 8.4635e-04 - mae: 0.0197 - root_mean_squared_error: 0.0290 - val_loss: 0.0011 - val_mae: 0.0260 - val_root_mean_squared_error: 0.0325
# Epoch 9/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 16s 29ms/step - loss: 7.7862e-04 - mae: 0.0192 - root_mean_squared_error: 0.0279 - val_loss: 7.4399e-04 - val_mae: 0.0190 - val_root_mean_squared_error: 0.0273
# Epoch 10/10
# 551/551 ━━━━━━━━━━━━━━━━━━━━ 16s 29ms/step - loss: 8.1525e-04 - mae: 0.0195 - root_mean_squared_error: 0.0285 - val_loss: 6.6733e-04 - val_mae: 0.0170 - val_root_mean_squared_error: 0.0258
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# Best Hyperparameters: <keras_tuner.src.engine.hyperparameters.hyperparameters.HyperParameters object at 0x000002B782ADC620>
# Best MAE: 0.00044270527968482483
# Worst Hyperparameters: <keras_tuner.src.engine.hyperparameters.hyperparameters.HyperParameters object at 0x000002B769FB0B90>
# Worst MAE: 0.0008076776751396777
# Nested Cross-Validation Scores:
# /nFold 1 - MSE: 0.0005966702812887323, R^2: 0.8817941951858077, RMSE: 0.024426835269611417, MAE: 0.016319666011332085
# /nFold 2 - MSE: 0.0003998797227080341, R^2: 0.9194752158547522, RMSE: 0.019996992841625816, MAE: 0.012402290280804636
# /nFold 3 - MSE: 0.0004412116259100256, R^2: 0.9106557025915293, RMSE: 0.02100503810779751, MAE: 0.01254015926641095
# /nFold 4 - MSE: 0.000392653963156137, R^2: 0.9198047089052916, RMSE: 0.019815498054708013, MAE: 0.011942204050206247
# /nFold 5 - MSE: 0.00044706413269851895, R^2: 0.9137366649621903, RMSE: 0.021143891143744542, MAE: 0.01234530319146682

# %% [markdown]
# Nested cross validation scores

# %%
print("Nested Cross-Validation Scores:")
for i, scores in enumerate(nested_scores):
    print(f"\nFold {i + 1} - MSE: {scores['Worst Model']['MSE']}, R^2: {scores['Worst Model']['R^2']}, RMSE: {scores['Worst Model']['RMSE']}, MAE: {scores['Worst Model']['MAE']}, time: {scores['Worst Model']['testing time']}")
    #, kge: {scores['Worst Model']['kge']}, nse: {scores['Worst Model']['nse']}, time: {scores['Worst Model']['testing time']}")

# Calculate overall statistics
all_mse = [scores['Worst Model']['MSE'] for scores in nested_scores]
all_mae = [scores['Worst Model']['MAE'] for scores in nested_scores]
all_rsme = [scores['Worst Model']['RMSE'] for scores in nested_scores]
all_r2 = [scores['Worst Model']['R^2'] for scores in nested_scores]
# all_kge = [scores['Worst Model']['kge'] for scores in nested_scores]
# all_nse = [scores['Worst Model']['nse'] for scores in nested_scores]
all_time = [scores['Worst Model']['testing time'] for scores in nested_scores]
mean_mse = np.mean(all_mse)
mean_mae = np.mean(all_mae)
mean_rsme = np.mean(all_rsme)
mean_r2 = np.mean(all_r2)
# mean_kge = np.mean(all_kge)
# mean_nse = np.mean(all_nse)
mean_time = np.mean(all_time)

print(f"Mean MSE: {mean_mse:.3f}")
print(f"Mean MAE: {mean_mae:.3f}")
print(f"Mean RMSE: {mean_rsme:.3f}")
print(f"Mean R^2: {mean_r2:.3f}")
# print(f"Mean kge: {mean_kge:.3f}")
# print(f"Mean nse: {mean_nse:.3f}")
print(f"Mean time: {mean_time:.3f}")
# Out:
# Nested Cross-Validation Scores:
#
# Fold 1 - MSE: 0.000736971045361422, R^2: 0.8539993388751527, RMSE: 0.02714721063684853, MAE: 0.017842465346610627, time: 7.306775808334351
#
# Fold 2 - MSE: 0.0007519856561462278, R^2: 0.8485707596488715, RMSE: 0.027422356867093458, MAE: 0.01811699308092137, time: 2.2317347526550293
#
# Fold 3 - MSE: 0.0007621543228858318, R^2: 0.8456655752109544, RMSE: 0.027607142606322587, MAE: 0.018153260598172214, time: 2.6828508377075195
#
# Fold 4 - MSE: 0.0007452706486481685, R^2: 0.8477865952701059, RMSE: 0.027299645577336138, MAE: 0.01761352554320646, time: 2.377141237258911
#
# Fold 5 - MSE: 0.0007779326557295777, R^2: 0.8498938733622189, RMSE: 0.02789144413130266, MAE: 0.018221987614807054, time: 2.1487789154052734
# Mean MSE: 0.001
# Mean MAE: 0.018
# Mean RMSE: 0.027
# Mean R^2: 0.849
# Mean time: 3.349

# %% [markdown]
# using the nested_scores as needed

# %%
# Print or use the nested_scores as needed
print("Nested Cross-Validation Scores:")
for i, scores in enumerate(nested_scores):
    print(f"\nFold {i + 1} - MSE: {scores['Best Model']['MSE']}, R^2: {scores['Best Model']['R^2']}, RMSE: {scores['Best Model']['RMSE']}, MAE: {scores['Best Model']['MAE']}")
    #, kge: {scores['Best Model']['kge']}, nse: {scores['Best Model']['nse']}")

# Calculate overall statistics
all_mse = [scores['Best Model']['MSE'] for scores in nested_scores]
all_mae = [scores['Best Model']['MAE'] for scores in nested_scores]
all_rsme = [scores['Best Model']['RMSE'] for scores in nested_scores]
all_r2 = [scores['Best Model']['R^2'] for scores in nested_scores]
# all_kge = [scores['Best Model']['kge'] for scores in nested_scores]
# all_nse = [scores['Best Model']['nse'] for scores in nested_scores]
all_time = [scores['Best Model']['testing time'] for scores in nested_scores]
mean_mse = np.mean(all_mse)
mean_mae = np.mean(all_mae)
mean_rsme = np.mean(all_rsme)
mean_r2 = np.mean(all_r2)
# mean_kge = np.mean(all_kge)
# mean_nse = np.mean(all_nse)
mean_time = np.mean(all_time)

print(f"Mean MSE: {mean_mse:.3f}")
print(f"Mean MAE: {mean_mae:.3f}")
print(f"Mean RMSE: {mean_rsme:.3f}")
print(f"Mean R^2: {mean_r2:.3f}")
# print(f"Mean kge: {mean_kge:.3f}")
# print(f"Mean nse: {mean_nse:.3f}")
print(f"Mean time: {mean_time:.3f}")
# Out:
# Nested Cross-Validation Scores:
#
# Fold 1 - MSE: 0.0005966702812887323, R^2: 0.8817941951858077, RMSE: 0.024426835269611417, MAE: 0.016319666011332085
#
# Fold 2 - MSE: 0.0003998797227080341, R^2: 0.9194752158547522, RMSE: 0.019996992841625816, MAE: 0.012402290280804636
#
# Fold 3 - MSE: 0.0004412116259100256, R^2: 0.9106557025915293, RMSE: 0.02100503810779751, MAE: 0.01254015926641095
#
# Fold 4 - MSE: 0.000392653963156137, R^2: 0.9198047089052916, RMSE: 0.019815498054708013, MAE: 0.011942204050206247
#
# Fold 5 - MSE: 0.00044706413269851895, R^2: 0.9137366649621903, RMSE: 0.021143891143744542, MAE: 0.01234530319146682
# Mean MSE: 0.000
# Mean MAE: 0.013
# Mean RMSE: 0.021
# Mean R^2: 0.909
# Mean time: 3.349

# %% [markdown]
# graph plotting

# %%
import matplotlib.pyplot as plt

# Assuming you have arrays y_pred and y_observed
# y_pred and y_observed should have the same length
y_pred = best_model.predict(X).flatten()
y_observed = y
plt.figure(figsize=(8, 8))
plt.scatter(y_observed, y_pred, color='blue', alpha=0.5)
plt.plot([min(y_observed), max(y_observed)], [min(y_observed), max(y_observed)], color='red', linestyle='--')
plt.title('Transformer')
plt.xlabel('Observed Flow')
plt.ylabel('Forecast Flow')
plt.grid(True)
plt.show()
# Out:
# 1033/1033 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step

# %% [markdown]
# C:\Users\Acer\Desktop\Testing

# %%
best_model.save(r'C:/Users/Administrator/Documents/GitHub/AQI_Forecasting/best_model_transformer_4i.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# optimizer test

# %%
# Assuming best_model is your trained model
optimizer = best_model.optimizer
learning_rate = float(optimizer.learning_rate.numpy())

# Print the optimizer and learning rate
print("Optimizer:", type(optimizer).__name__)
print("Learning Rate:", learning_rate)
# Out:
# Optimizer: Adam
# Learning Rate: 0.004838874563574791

# %%
# Assuming best_model is your trained model

# Function to extract dropout rate from a layer
def get_dropout_rate(layer):
    if hasattr(layer, 'rate'):
        return layer.rate
    elif hasattr(layer, 'dropout'):
        return layer.dropout
    else:
        return None

# Iterate through layers of the model and find the dropout rates
dropout_rates = []

for layer in best_model.layers:
    rate = get_dropout_rate(layer)
    if rate is not None:
        dropout_rates.append((layer.name, rate))

# Print the dropout rates
print("Dropout Rates:")
for layer_name, rate in dropout_rates:
    print(f"{layer_name}: {rate}")
# Out:
# Dropout Rates:
# multi_head_attention_82: 0.5412287526006545
# dropout_272: 0.5412287526006545
# dropout_273: 0.5412287526006545
# multi_head_attention_83: 0.28001793190890045
# dropout_275: 0.28001793190890045
# dropout_276: 0.28001793190890045
# dropout_277: 0.23760553154266215

# %%
best_hyperparameters_dict = best_model_hyperparameters.values
worst_hyperparameters_dict = worst_model_hyperparameters.values

print("Best Hyperparameters:", best_hyperparameters_dict)
print("Worst Hyperparameters:", worst_hyperparameters_dict)
# Out:
# Best Hyperparameters: {'num_transformer_blocks': 2, 'head_size': 8, 'num_heads': 5, 'ff_dim': 47, 'dropout_0': 0.5412287526006545, 'dropout_1': 0.28001793190890045, 'num_mlp_layers': 1, 'mlp_units_0': 64, 'mlp_dropout_0': 0.23760553154266215, 'optimizer': 'adam', 'learning_rate': 0.0048388747178456015, 'dropout_2': 0.41768101831711646, 'dropout_3': 0.1034211257436968, 'dropout_4': 0.19370464203013907, 'dropout_5': 0.2808861593639089, 'dropout_6': 0.3305912270746363, 'dropout_7': 0.3469607804047361, 'mlp_units_1': 192, 'mlp_dropout_1': 0.4017655606404176, 'mlp_units_2': 256, 'mlp_dropout_2': 0.1320979007863666}
# Worst Hyperparameters: {'num_transformer_blocks': 2, 'head_size': 232, 'num_heads': 14, 'ff_dim': 8, 'dropout_0': 0.21610378865518273, 'dropout_1': 0.4587220527536823, 'num_mlp_layers': 1, 'mlp_units_0': 96, 'mlp_dropout_0': 0.3550303557587068, 'optimizer': 'adam', 'learning_rate': 0.005996001858144324}

# %%
# from keras.utils import plot_model
# # Visualize the model architecture and save the diagram to a file
# plot_model(best_model, to_file='tf_model.png', show_shapes=True, show_layer_names=True

# %%
# Assuming best_model is your trained model

# Function to extract dropout rate from a layer
def get_dropout_rate(layer):
    if hasattr(layer, 'rate'):
        return layer.rate
    elif hasattr(layer, 'dropout'):
        return layer.dropout
    else:
        return None

# Iterate through layers of the model and find the dropout rates
dropout_rates = []

for layer in best_model.layers:
    rate = get_dropout_rate(layer)
    if rate is not None:
        dropout_rates.append((layer.name, rate))

# Print the dropout rates
print("Dropout Rates:")
for layer_name, rate in dropout_rates:
    print(f"{layer_name}: {rate}")
# Out:
# Dropout Rates:
# multi_head_attention_82: 0.5412287526006545
# dropout_272: 0.5412287526006545
# dropout_273: 0.5412287526006545
# multi_head_attention_83: 0.28001793190890045
# dropout_275: 0.28001793190890045
# dropout_276: 0.28001793190890045
# dropout_277: 0.23760553154266215

# %%
# Print or use the nested_scores as needed
print("Nested Cross-Validation Scores:")
for i, scores in enumerate(nested_scores):
    print(f"\nFold {i + 1} - MSE: {scores['Best Model']['MSE']}, R^2: {scores['Best Model']['R^2']}, RMSE: {scores['Best Model']['RMSE']}, MAE: {scores['Best Model']['MAE']}")
    #, kge: {scores['Best Model']['kge']}, nse: {scores['Best Model']['nse']}")


# Calculate overall statistics
all_mse = [scores['Best Model']['MSE'] for scores in nested_scores]
all_mae = [scores['Best Model']['MAE'] for scores in nested_scores]
all_rsme = [scores['Best Model']['RMSE'] for scores in nested_scores]
all_r2 = [scores['Best Model']['R^2'] for scores in nested_scores]
# all_kge = [scores['Best Model']['kge'] for scores in nested_scores]
# all_nse = [scores['Best Model']['nse'] for scores in nested_scores]
all_time = [scores['Best Model']['testing time'] for scores in nested_scores]
mean_mse = np.mean(all_mse)
mean_mae = np.mean(all_mae)
mean_rsme = np.mean(all_rsme)
mean_r2 = np.mean(all_r2)
# mean_kge = np.mean(all_kge)
# mean_nse = np.mean(all_nse)
mean_time = np.mean(all_time)

print(f"Mean MSE: {mean_mse:.6f}")
print(f"Mean MAE: {mean_mae:.6f}")
print(f"Mean RMSE: {mean_rsme:.6f}")
print(f"Mean R^2: {mean_r2:.6f}")
# print(f"Mean kge: {mean_kge:.6f}")
# print(f"Mean nse: {mean_nse:.6f}")
print(f"Mean time: {mean_time:.6f}")
# Out:
# Nested Cross-Validation Scores:
#
# Fold 1 - MSE: 0.0005966702812887323, R^2: 0.8817941951858077, RMSE: 0.024426835269611417, MAE: 0.016319666011332085
#
# Fold 2 - MSE: 0.0003998797227080341, R^2: 0.9194752158547522, RMSE: 0.019996992841625816, MAE: 0.012402290280804636
#
# Fold 3 - MSE: 0.0004412116259100256, R^2: 0.9106557025915293, RMSE: 0.02100503810779751, MAE: 0.01254015926641095
#
# Fold 4 - MSE: 0.000392653963156137, R^2: 0.9198047089052916, RMSE: 0.019815498054708013, MAE: 0.011942204050206247
#
# Fold 5 - MSE: 0.00044706413269851895, R^2: 0.9137366649621903, RMSE: 0.021143891143744542, MAE: 0.01234530319146682
# Mean MSE: 0.000455
# Mean MAE: 0.013110
# Mean RMSE: 0.021278
# Mean R^2: 0.909093
# Mean time: 3.349456

# %%
# Assuming best_model is your trained model
optimizer = best_model.optimizer
learning_rate = float(optimizer.learning_rate.numpy())

# Print the optimizer and learning rate
print("Optimizer:", type(optimizer).__name__)
print("Learning Rate:", learning_rate)
# Out:
# Optimizer: Adam
# Learning Rate: 0.004838874563574791

# %%
# Assuming best_model is your final trained model
best_model.save(r'C:/Users/Administrator/Documents/GitHub/AQI_Forecasting/best_model_transformer.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# testing for fprecasted

# %%
y_test_outer = (y_test_outer - min(y_test_outer)) / (max(y_test_outer) - min(y_test_outer))
y_pred = (y_pred - min(y_pred)) / (max(y_pred) - min(y_pred))

# %%
import numpy as np
y_pred_smooth = np.convolve(y_pred, np.ones(3)/3, mode='same')  # Moving average

# %%
import numpy as np
y_pred_shifted = np.roll(y_pred, shift=-1)  # Shift left by 1

# %%
import matplotlib.pyplot as plt

# Assuming you have arrays y_pred and y_observed
# y_pred and y_observed should have the same length
y_pred = best_model.predict(X).flatten()
y_observed = y
plt.figure(figsize=(8, 8))
plt.scatter(y_observed, y_pred, color='blue', alpha=0.5)
plt.plot([min(y_observed), max(y_observed)], [min(y_observed), max(y_observed)], color='red', linestyle='--')
plt.title('Transformer')
plt.xlabel('Observed Flow')
plt.ylabel('Forecast Flow')
plt.grid(True)
plt.show()
# Out:
# 1033/1033 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step

# %%
import matplotlib.pyplot as plt
import numpy as np

# Function to apply a moving average for smoothing
def moving_average(data, window_size=3):
    return np.convolve(data, np.ones(window_size)/window_size, mode='same')

# Apply smoothing to Forecast values
y_pred_smoothed = moving_average(y_pred[:100], window_size=5)

# Increase figure size
plt.figure(figsize=(12, 6))

# Plot actual and smoothed Forecast values
plt.plot(y_test_outer[:100], color='red', linestyle='solid', linewidth=2, alpha=0.8, label='Actual Pollution Level')
plt.plot(y_pred_smoothed, color='green', linestyle='dashed', linewidth=2, marker='o', markersize=4, alpha=0.8, label='Forecast Pollution Level (Smoothed)')

# Highlight future prediction area with subtle transparency
forecast_start = len(y_test_outer[:90])
forecast_end = len(y_test_outer[:100])
plt.axvspan(forecast_start, forecast_end, color='green', alpha=0.15, label="Forecasted Region")

# Add vertical dashed lines to indicate the forecast boundary
plt.axvline(x=forecast_start, color='green', linestyle='dashed', alpha=0.6)
plt.axvline(x=forecast_end, color='green', linestyle='dashed', alpha=0.6)

# Improve labels and title
plt.title("Transformer Forecasting - Actual vs. Forecast Pollution Levels", fontsize=14, fontweight='bold')
plt.xlabel("Time (Days)", fontsize=12)
plt.ylabel("PM2.5 Pollution Level", fontsize=12)

# Optional: Use log scale for better visibility (comment out if not needed)
# plt.yscale('log')

# Add grid for readability
plt.grid(True, linestyle='--', alpha=0.5)

# Adjust legend position outside the plot to avoid overlap
plt.legend(loc='upper left', fontsize=12, frameon=True)

# Save the improved plot (uncomment if needed)
# plt.savefig('improved_graph.png', dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

# %% [markdown]
# forecasted graph testing

# %%
import matplotlib.pyplot as plt

# Increase figure size
plt.figure(figsize=(12, 6))

# Plot actual and Forecast values with improved styling
plt.plot(y_test_outer[50:100], color='red', linestyle='solid', linewidth=2, label='Actual Pollution Level')
plt.plot(y_pred[50:100], color='green', linestyle='dashed', linewidth=2, marker='o', markersize=4, label='Forecast Pollution Level')

# Highlight future prediction area
plt.axvspan(len(y_test_outer[50:100]), len(y_test_outer[50:100]), color='green', alpha=0.2, label="Forecasted Region")

# Improve labels and title
plt.title("LSTM Forecasting - Actual vs. Forecast Pollution Levels", fontsize=14)
plt.xlabel("Time (Days)", fontsize=12)
plt.ylabel("PM2.5 Pollution Level", fontsize=12)

# Add grid for readability
plt.grid(True, linestyle='--', alpha=0.5)

# Adjust legend position
plt.legend(loc='upper left', fontsize=12)

# Save the improved plot
# plt.savefig('improved_graph.png', dpi=300)

# Show the plot
plt.show()

# %% [markdown]
# forecasting curve testing 2

# %%
import matplotlib.pyplot as plt

# Increase figure size for better visibility
plt.figure(figsize=(12, 6))

# Define x-axis range for correct alignment
x_range = range(len(y_test_outer[50:100]))

# Plot actual pollution levels
plt.plot(x_range, y_test_outer[50:100], color='red', linestyle='solid', linewidth=2, label='Actual Pollution Level')

# Plot Forecast pollution levels
plt.plot(x_range, y_pred[50:100], color='green', linestyle='dashed', linewidth=2, marker='o', markersize=4, label='Forecast Pollution Level')

# Improve labels and title
plt.title("LSTM Forecasting - Actual vs. Forecast Pollution Levels", fontsize=14)
plt.xlabel("Time (Days)", fontsize=12)
plt.ylabel("PM2.5 Pollution Level", fontsize=12)

# Add grid for better readability
plt.grid(True, linestyle='--', alpha=0.5)

# Adjust legend position
plt.legend(loc='upper left', fontsize=12)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Normalize actual and Forecast values to the same scale
y_test_scaled = (y_test_outer[50:100] - min(y_test_outer)) / (max(y_test_outer) - min(y_test_outer))
y_pred_scaled = (y_pred[50:100] - min(y_pred)) / (max(y_pred) - min(y_pred))

# Apply moving average to smooth predictions
y_pred_smooth = np.convolve(y_pred_scaled, np.ones(3)/3, mode='same')

# Shift predictions slightly to align better
y_pred_shifted = np.roll(y_pred_smooth, shift=-1)  

# Define x-axis range for correct alignment
x_range = range(len(y_test_scaled))

# Increase figure size for better visibility
plt.figure(figsize=(12, 6))

# Plot actual pollution levels (normalized)
plt.plot(x_range, y_test_scaled, color='red', linestyle='solid', linewidth=2, label='Actual Pollution Level')

# Plot Forecast pollution levels (smoothed & shifted)
plt.plot(x_range, y_pred_shifted, color='green', linestyle='dashed', linewidth=2, marker='o', markersize=4, label='Forecast Pollution Level')

# Improve labels and title
plt.title("LSTM Forecasting - Actual vs. Forecast Pollution Levels", fontsize=14)
plt.xlabel("Time (Days)", fontsize=12)
plt.ylabel("Normalized PM2.5 Pollution Level", fontsize=12)

# Add grid for better readability
plt.grid(True, linestyle='--', alpha=0.5)

# Adjust legend position
plt.legend(loc='upper left', fontsize=12)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate forecasted values using the best model
y_pred_best = best_model.predict(X_test_outer)

# Create time steps (adjust based on your dataset size)
time_steps = np.arange(len(y_test_outer))

# Plot actual vs Forecast values
plt.figure(figsize=(10, 5))
plt.plot(time_steps, y_test_outer, label="Actual ", color="blue", marker='o', linestyle='dashed')
plt.plot(time_steps, y_pred_best, label="Forecast ", color="red", marker='x', linestyle='dashed')

# Labels and title
plt.xlabel("Time Steps")
plt.ylabel("Value")
plt.title("Forecasted vs Actual Air Quality (Best Model)")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()
# Out:
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate forecasted values using the best model
y_pred_best = best_model.predict(X_test_outer)

# Reduce the number of plotted points (every 10th point)
sampling_rate = 10  # Change this to control how much data to plot
time_steps = np.arange(len(y_test_outer))[::sampling_rate]
y_test_sampled = y_test_outer[::sampling_rate]
y_pred_sampled = y_pred_best[::sampling_rate]

# Plot actual vs Forecast values
plt.figure(figsize=(10, 5))
plt.plot(time_steps, y_test_sampled, label="Actual", color="blue", marker='o', linestyle='dashed')
plt.plot(time_steps, y_pred_sampled, label="Forecast", color="red", marker='x', linestyle='dashed')

# Labels and title
plt.xlabel("Time Steps")
plt.ylabel("Value")
plt.title("Forecasted vs Actual Air Quality (Best Model)")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()
# Out:
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate forecasted values using the best model
y_pred_best = best_model.predict(X_test_outer)

# Select 100 evenly spaced indices from the test set
num_points = 100
indices = np.linspace(0, len(y_test_outer) - 1, num_points, dtype=int)

# Subset the actual and Forecast values
time_steps = indices
y_test_sampled = y_test_outer[indices]
y_pred_sampled = y_pred_best[indices]

# Plot actual vs Forecast values
plt.figure(figsize=(10, 5))
plt.plot(time_steps, y_test_sampled, label="Actual", color="blue", marker='o', linestyle='dashed')
plt.plot(time_steps, y_pred_sampled, label="Forecast", color="red", marker='x', linestyle='dashed')

# Labels and title
plt.xlabel("Time Steps")
plt.ylabel("Value")
plt.title("Forecasted vs Actual Air Quality (Best Model)")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()
# Out:
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate forecasted values using the best model
y_pred_best = best_model.predict(X_test_outer)

# Select 100 evenly spaced indices from the test set
num_points = 100
indices = np.linspace(0, len(y_test_outer) - 1, num_points, dtype=int)

# Subset the actual and Forecast values
time_steps = indices
y_test_sampled = y_test_outer[indices]
y_pred_sampled = y_pred_best[indices]

# Define the forecasted region (last 10 points)
forecast_start = num_points - 10  # Last 10 points
forecast_x = time_steps[forecast_start:]
forecast_y_actual = y_test_sampled[forecast_start:]
forecast_y_pred = y_pred_sampled[forecast_start:]

# Plot actual pollution level in red
plt.figure(figsize=(12, 6))
plt.plot(time_steps, y_test_sampled, label="Actual Pollution Level", color="red", linestyle='solid', linewidth=1.5)

# Plot Forecast pollution level in green dashed line with markers
plt.plot(time_steps, y_pred_sampled, label="Forecasted Pollution Level", color="green", linestyle='dashed', marker='o', linewidth=1.5)

# Highlight forecasted region in shaded green
plt.axvspan(forecast_x[0], forecast_x[-1], color='green', alpha=0.2, label="Forecasted Region")

# Labels and title
plt.xlabel("Time (Days)", fontsize=12)
plt.ylabel("PM2.5 Pollution Level", fontsize=12)
plt.title("Transformer Forecasting - Actual vs. Forecast Pollution Levels", fontsize=14)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)

# Show the plot
plt.show()
# Out:
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %% [markdown]
# 100 days

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate forecasted values using the best model
y_pred_best = best_model.predict(X_test_outer)

# Select only 100 data points for a clearer x-axis
num_points = 100
indices = np.linspace(0, len(y_test_outer) - 1, num_points, dtype=int)

# Subset the actual and predicted values
time_steps = np.linspace(1, 100, num_points)  # Rescale x-axis to represent 100 days
y_test_sampled = y_test_outer[indices]
y_pred_sampled = y_pred_best[indices]

# Define the forecasted region (last 10 points)
forecast_start = num_points - 10  # Last 10 points
forecast_x = time_steps[forecast_start:]
forecast_y_actual = y_test_sampled[forecast_start:]
forecast_y_pred = y_pred_sampled[forecast_start:]

# Plot actual pollution level in red
plt.figure(figsize=(12, 6))
plt.plot(time_steps, y_test_sampled, label="Actual Pollution Level", color="red", linestyle='solid', linewidth=1.5)

# Plot predicted pollution level in green dashed line with markers
plt.plot(time_steps, y_pred_sampled, label="Forecasted Pollution Level", color="green", linestyle='dashed', marker='o', linewidth=1.5)

# Highlight forecasted region in shaded green
plt.axvspan(forecast_x[0], forecast_x[-1], color='green', alpha=0.2, label="Forecasted Region")

# Labels and title
plt.xlabel("Time (Days)", fontsize=12)
plt.ylabel("PM2.5 Pollution Level", fontsize=12)
plt.title("Transformer Forecasting - Actual vs. Forecast Pollution Levels", fontsize=14)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)

# Show the plot
plt.show()
# Out:
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
